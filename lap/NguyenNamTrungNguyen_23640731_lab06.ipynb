# %% [markdown]
# # Lab 06 - Bài Tập

# %%
# Bài Tập Thực Hành Số 6
# Họ Và Tên: Nguyễn Nam Trung Nguyên
# MSSV: 23640731
# Số câu đã làm : 8/8

# %% [markdown]
# ### Bài 1: Tạo quần thể mô phỏng
#
# Bạn hãy tạo một mẫu gồm 10000 phần tử mô phỏng chiều cao của nam thanh niên có giá trị từ 120cm - 200cm. Bạn hãy lưu kết quả vào biến **POP**.
#
# Tính:
# a. Chiều cao trung bình (kỳ vọng) của quần thể và độ lệch chuẩn về chiều cao của quần thể.
#
# b. Tính tỷ lệ người cao trong quần thể, biết rằng thanh niên có chiều cao từ 180 trở lên được gọi là cao.
#
# c. Vẽ histogram về chiều cao của quần thể. Theo bạn quần thể có phân phối chuẩn hay không?
#
# d. Thử vẽ histogram và đồ thị hàm mật độ của phân phối chuẩn sử dụng tham số loc và scale bằng với kỳ vọng và độ lệch chuẩn của quần thể.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

np.random.seed(42)

POP = np.random.normal(loc=165, scale=10, size=10000)
POP = np.clip(POP, 120, 200)

# 1a
mean_height = np.mean(POP)
std_height = np.std(POP)
print("Câu 1a:")
print("Mean:", mean_height)
print("Std:", std_height)

# 1b
tall_ratio = np.sum(POP >= 180) / len(POP)
print("Câu 1b:")
print("Tỷ lệ người cao:", tall_ratio)

# 1c
print("Câu 1c:")
plt.hist(POP, bins=30)
plt.show()

# 1d
x = np.linspace(120, 200, 1000)
pdf = norm.pdf(x, loc=mean_height, scale=std_height)

print("Câu 1d:")
plt.hist(POP, bins=30, density=True)
plt.plot(x, pdf)
plt.show()
# Out:
# Câu 1a:
# Mean: 164.9778321419311
# Std: 10.031148450690683
# Câu 1b:
# Tỷ lệ người cao: 0.0676
# Câu 1c:
# Câu 1d:

# %% [markdown]
# ### Bài 2: Lấy mẫu cỡ 20
#
# Bạn hãy lấy một mẫu kích thước 20 phần từ. Tính:
#
# a. Trung bình mẫu, và độ lệch chuẩn của mẫu
#
# b. Tỷ lệ người cao của mẫu
#
# c. Vẽ histogram của mẫu
#
# d. Thử vẽ đồ thị hàm mật độ của phân phối chuẩn với tham số loc và scale bằng với giá trị trung bình và độ lệch chuẩn và chiều cao của mẫu. Bạn có nhận xét gì không?

# %%
sample = np.random.choice(POP, size=20, replace=False)

# 2a
sample_mean = np.mean(sample)
sample_std = np.std(sample)
print("Câu 2a:")
print("Mean:", sample_mean)
print("Std:", sample_std)

# 2b
sample_tall_ratio = np.sum(sample >= 180) / len(sample)
print("Câu 2b:")
print("Tỷ lệ người cao:", sample_tall_ratio)

# 2c
print("Câu 2c:")
plt.hist(sample, bins=10)
plt.show()

# 2d
x2 = np.linspace(min(sample), max(sample), 1000)
pdf2 = norm.pdf(x2, loc=sample_mean, scale=sample_std)
print("Câu 2d:")
plt.hist(sample, bins=10, density=True)
plt.plot(x2, pdf2)
plt.show()
# Out:
# Câu 2a:
# Mean: 164.1380098845813
# Std: 10.949870706770893
# Câu 2b:
# Tỷ lệ người cao: 0.05
# Câu 2c:
# Câu 2d:

# %% [markdown]
# ### Bài 3: Lấy mẫu cỡ 100
#
# Lặp lại thí nghiệm bài 2 với cỡ mẫu là 100

# %%
sample100 = np.random.choice(POP, size=100, replace=False)

# 3a
sample100_mean = np.mean(sample100)
sample100_std = np.std(sample100)
print("Câu 3a:")
print("Mean:", sample100_mean)
print("Std:", sample100_std)

# 3b
sample100_tall_ratio = np.sum(sample100 >= 180) / len(sample100)
print("Câu 3b:")
print("Tỷ lệ người cao:", sample100_tall_ratio)

# 3c
print("Câu 3c:")
plt.hist(sample100, bins=15)
plt.show()

# 3d
x3 = np.linspace(min(sample100), max(sample100), 1000)
pdf3 = norm.pdf(x3, loc=sample100_mean, scale=sample100_std)
print("Câu 3d:")
plt.hist(sample100, bins=15, density=True)
plt.plot(x3, pdf3)
plt.show()
# Out:
# Câu 3a:
# Mean: 164.82331432904456
# Std: 8.458392127390109
# Câu 3b:
# Tỷ lệ người cao: 0.05
# Câu 3c:
# Câu 3d:

# %% [markdown]
# ### Bài 4: Khảo sát phân phối của trung bình mẫu
#
# a. Thực hiện bài 2 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# b. Thực hiện bài 3 100 lần, mỗi lần bạn tính được trung bình mẫu. Vẽ đồ thị histogram cho 100 trung bình mẫu bạn tính được.
#
# c. Vẽ histogram của hai câu a, b trong cùng một hình để so sánh. Theo bạn hình dạng của histogram thay đổi nói lên điều gì?
#
# Gợi ý: tạo một danh sách rỗng để chứa các trung bình mẫu tính được, sử dụng hàm append() để thêm giá trị trung bình vào danh sách sau mỗi lần tính.

# %%
# 4a
means_20 = []
for _ in range(100):
    s = np.random.choice(POP, size=20, replace=False)
    means_20.append(np.mean(s))

print("Câu 4a:")
plt.hist(means_20, bins=15)
plt.show()

# 4b
means_100 = []
for _ in range(100):
    s = np.random.choice(POP, size=100, replace=False)
    means_100.append(np.mean(s))

print("Câu 4b:")
plt.hist(means_100, bins=15)
plt.show()

# 4c
print("Câu 4c:")
plt.hist(means_20, bins=15, alpha=0.5)
plt.hist(means_100, bins=15, alpha=0.5)
plt.show()
# Out:
# Câu 4a:
# Câu 4b:
# Câu 4c:

# %% [markdown]
# ### Bài 5: Khảo sát tỷ lệ mẫu
#
# a. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram tỷ lệ người cao của các mẫu
#
# b. Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 500. Vẽ histogram tỷ lệ người cao của các mẫu

# %%
# 5a
ratios_100 = []
for _ in range(1000):
    s = np.random.choice(POP, size=100, replace=False)
    ratios_100.append(np.sum(s >= 180) / len(s))

print("Câu 5a:")
plt.hist(ratios_100, bins=20)
plt.show()

# 5b
ratios_500 = []
for _ in range(1000):
    s = np.random.choice(POP, size=500, replace=False)
    ratios_500.append(np.sum(s >= 180) / len(s))

print("Câu 5b:")
plt.hist(ratios_500, bins=20)
plt.show()
# Out:
# Câu 5a:
# Câu 5b:

# %% [markdown]
# ### Bài 6: Khảo sát phương sai mẫu
#
# Bạn hãy mô phỏng 1000 lần lấy mẫu có kích cỡ 100. Vẽ histogram đại lượng phương sai của các mẫu (Phương sai bằng bình phương độ lệch chuẩn)

# %%
# 6
variances_100 = []
for _ in range(1000):
    s = np.random.choice(POP, size=100, replace=False)
    variances_100.append(np.var(s))

print("Câu 6:")
plt.hist(variances_100, bins=20)
plt.show()
# Out:
# Câu 6:

# %% [markdown]
# ### Bài 7:  Bài Tập Ước Lượng
#
# Khảo sát cân nặng (kg) của gà khi xuất chuồng, người ta cân một số con và có kết quả như sau:
#
# > 2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8
#
# Giả sử cân nặng của gà là biến ngẫu nhiên có phân phối chuẩn. Hãy lập khoảng tin cậy cho cân nặng trung bình của  khi xuất chuồng với độ tin cậy là 95%. Trong 2 trường hợp:
#
# a, Biết $\sigma = 0.3$
#
# b, Không biết $\sigma$

# %%
# 7
data = np.array([2.1, 1.8, 2.0, 2.3, 1.7, 1.5, 2.0, 2.2, 1.8])
n = len(data)
mean_data = np.mean(data)

# 7a
sigma = 0.3
z = norm.ppf(0.975)
ci_lower_a = mean_data - z * sigma / np.sqrt(n)
ci_upper_a = mean_data + z * sigma / np.sqrt(n)
print("Câu 7a:")
print("CI:", ci_lower_a, ci_upper_a)

# 7b
from scipy.stats import t
s = np.std(data, ddof=1)
t_val = t.ppf(0.975, df=n-1)
ci_lower_b = mean_data - t_val * s / np.sqrt(n)
ci_upper_b = mean_data + t_val * s / np.sqrt(n)
print("Câu 7b:")
print("CI:", ci_lower_b, ci_upper_b)
# Out:
# Câu 7a:
# CI: 1.7373369348793277 2.1293297317873385
# Câu 7b:
# CI: 1.7373606652839864 2.12930600138268

# %% [markdown]
# ### Bài 8
#
# Bộ dữ liệu `SAT-lard.csv` chứa điểm thi SAT của 1000 học sinh.
#
# a. Giả sử bộ dữ liệu là kết quả của quá trình lấy mẫu ngẫu nhiên từ các học sinh. Bạn hãy xây dựng khoảng tin cậy cho trung bình điểm thi của tất cả các sinh viên với độ tin cậy 99% (`Đáp án: 105.2 ± 3.10`)
#
# b. Giả sử bộ dữ liệu là kết quả của quá trình lấy mẫu ngẫu nhiên từ các học sinh. Bạn hãy xây dựng khoảng tin cậy cho trung bình điểm thi của tất cả các sinh viên với độ tin cậy (`Đáp án: 105.2 ± 1.86`)
#
# c. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Tính điểm SAT trung bình của trường phổ thông đấy. (`Đáp án:  μ = 1528.74`)
#
# d. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Sử dụng mẫu là điểm thi của 36 học sinh đầu tiên trong bộ dữ liệu, bạn hãy xây dựng khoảng tin cậy **99%** cho điểm SAT trung bình của trường phổ thông đấy. (`Đáp án: (1428.22, 1602.89)`)
#
# e. Giả sử bộ dữ liệu là toàn bộ kết quả điểm thi SAT của học sinh một trường phố thông. Sử dụng mẫu là điểm thi của 36 học sinh đầu tiên trong bộ dữ liệu, bạn hãy xây dựng khoảng tin cậy **95%** cho điểm SAT trung bình của trường phổ thông đấy. Cho biết khoảng ước lượng bạn xây dựng có đúng không, dựa trên giá trị đã tính ở câu trên.

# %%
# 8
import pandas as pd
from scipy.stats import t

df = pd.read_csv('SAT-lard.csv')

# 8a
scores = df.iloc[:,0]
n = len(scores)
mean_scores = np.mean(scores)
s_scores = np.std(scores, ddof=1)

t_val_99 = t.ppf(0.995, df=n-1)
margin_99 = t_val_99 * s_scores / np.sqrt(n)
print("Câu 8a:")
print("CI:", mean_scores - margin_99, mean_scores + margin_99)

# 8b
t_val_95 = t.ppf(0.975, df=n-1)
margin_95 = t_val_95 * s_scores / np.sqrt(n)
print("Câu 8b:")
print("CI:", mean_scores - margin_95, mean_scores + margin_95)

# 8c
print("Câu 8c:")
print("Mean:", mean_scores)

# 8d
sample36 = scores.iloc[:36]
n36 = len(sample36)
mean36 = np.mean(sample36)
s36 = np.std(sample36, ddof=1)

t36_99 = t.ppf(0.995, df=n36-1)
margin36_99 = t36_99 * s36 / np.sqrt(n36)
print("Câu 8d:")
print("CI:", mean36 - margin36_99, mean36 + margin36_99)

# 8e
t36_95 = t.ppf(0.975, df=n36-1)
margin36_95 = t36_95 * s36 / np.sqrt(n36)
print("Câu 8e:")
print("CI:", mean36 - margin36_95, mean36 + margin36_95)
# Out:
# Câu 8a:
# CI: 1511.3939951002396 1546.0860048997604
# Câu 8b:
# CI: 1515.550556043932 1541.929443956068
# Câu 8c:
# Mean: 1528.74
# Câu 8d:
# CI: 1423.171232801838 1607.9398783092734
# Câu 8e:
# CI: 1446.6996332344288 1584.4114778766825
